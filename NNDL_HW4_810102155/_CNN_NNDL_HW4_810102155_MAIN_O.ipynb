# %% [markdown]
# # Use ParsBert

# %%
# # # Install necessary libraries
# !pip install transformers
# !pip install hazm

# %%
import pandas as pd
from transformers import AutoTokenizer
from hazm import Normalizer


tokenizer = AutoTokenizer.from_pretrained("HooshvareLab/bert-base-parsbert-uncased")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/434 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.22M [00:00<?, ?B/s]

# %%
from google.colab import drive
drive.mount('/content/drive' , force_remount=True)

import pandas as pd

file_path1 = '/content/drive/MyDrive/persian-tweets-emotional-dataset/anger.csv'
file_path2 = '/content/drive/MyDrive/persian-tweets-emotional-dataset/disgust.csv'
file_path3 = '/content/drive/MyDrive/persian-tweets-emotional-dataset/fear.csv'

file_path4 = '/content/drive/MyDrive/persian-tweets-emotional-dataset/joy.csv'
file_path5 = '/content/drive/MyDrive/persian-tweets-emotional-dataset/sad.csv'
file_path6 = '/content/drive/MyDrive/persian-tweets-emotional-dataset/surprise.csv'


df1 = pd.read_csv(file_path1)
df2 = pd.read_csv(file_path2)
df3 = pd.read_csv(file_path3)

df4 = pd.read_csv(file_path4)
df5 = pd.read_csv(file_path5)
df6 = pd.read_csv(file_path6)

import pandas as pd

df = pd.concat([df1, df2, df3, df4, df5, df6], ignore_index = True)

df = df.sample(frac=1).reset_index(drop = True)
# Out:
# Mounted at /content/drive

# %%
stopwords = ['و', 'در', 'به' ,
             'از' , 'که' , 'این' , 'است',
             'این' , 'می' , 'را' , 'با' , 'های' , 'برای' , 'آن' , 'یک' ,
             'برای' , 'های' ,
             'خود' , 'ها' , 'کرد' , 'شد' , 'ای' , 'تا' ,
             'کند' , 'بر' , 'بود' , 'گفت' ,
             'نیز' , 'وی' , 'هم' , 'کنند' , 'دارد' , 'ما' , 'کرده' ,
             'یا' , 'اما' , 'باید' ,
             'دو' , 'اند' , 'هر' , 'خواهد' , 'او' , 'مورد' , 'باشد' ,
             'دیگر' , 'بین' , 'پیش' ,
             'پس' , 'اگر' , 'همه' , 'صورت' , 'یکی' , 'هستند' , 'من' , 'دهد' ,
             'نیست' , 'استفاده' ,
             'داد' , 'داشته' , 'راه' , 'داشت' , 'چه' , 'همچنین' ,
             'کردند' , 'داده' , 'بوده' , 'دارند' ,
             'همین' , 'سوی' , 'شوند' , 'بسیار' , 'روی' , 'گرفته‌اند' ,
             'هایی' , 'تواند' , 'حتی' , 'اینکه' ,
             'این‌که' , 'ولی' , 'توسط' , 'چنین' , 'برخی' ,
             'درباره' , 'گیرد' , 'گفته' , 'آنان' ,
             'بار' , 'طور' , 'گرفت' , 'دهند' , 'گذاری' , 'بسیاری' ,
             'طی' , 'بودند' , 'براساس' , 'شدند' ,
             'باشند' , 'چون' , 'قابل' , 'گوید' , 'دیگری' , 'همان' , 'خواهند' ,
             'طریق' , 'آمده' , 'تحت' ,
             'گیری' , 'جای' , 'سازی' , 'کنم' , 'زیر' , 'توانند' , 'ضمن' ,
             'فقط' , 'بودن' , 'آید' ,
             'اش' , 'ام' , 'ات' , 'آورد' , 'امان' , 'اتان' , 'اشان' ,
             'آنچه' , 'ریزی' ,
             'بنابراین' , 'بعضی' , 'برخی' , 'دادند' , 'داشتند' ,
             'زیر' , 'روی' , 'سری' , 'توی' , 'جلوی' ,
             'پیش' , 'عقب' , 'بالای' , 'خارج' , 'وسط' , 'بیرون' , 'سوی' , 'کنار' ,
             'نزد' , 'دنبال' ,
             'حدود' , 'برابر' , 'اثر' , 'علت' , 'عنوان' , 'قصد' , 'جدا' ,
             'کی' , 'که' , 'چیست' ,
             'هست' , 'کجا' , 'کجاست' , 'چطور' , 'کدام' , 'آیا' , 'مگر' ,
             'چندین' , 'یک' , 'چیزی' ,
             'دیگر' , 'کسی' , 'چیز' , 'جا' , 'کس' , 'لطفا' , 'تان' , 'مان' ,
             'هنگامی' , 'وقتیکه' ,
             'مدتی' ,
             'آنکه' , 'انکه' , 'خواهشا' , 'وقتیکه'
             ]

# print('----------- length of stopwords ---------------')
# print(len(stopwords))
# print('-----------------------------------------------')
# print('مدتی' in stopwords)

# %%
emoji_mapping = {
    '😊': 'خندان',
    '😢': 'غمگین',
    '😂': 'خنده',
    '😍': 'عاشق',
    '❤️': 'عشق',
    '👍': 'خوب',
    '👎': 'بد',
    '🙏': 'دعا',
    '🔥': 'آتش',
    '🔴' : 'قرمز' ,
    '🟡' : 'زرد' ,
    '✊' : 'مشت' ,
    '💥' : 'هیجان' ,
    '📡' : 'فوری' ,
    '⬅️' : 'تماشا' ,
    '🇮🇷' : 'ایران' ,
    '✌' : 'دوباره' ,
    '💔': 'شکسته',
    '🌸': 'گل',
    '🌞': 'خورشید',
    '🌈': 'رنگین‌کمان',
    '🎉': 'تبریک',
    '🤗': 'دوستانه',
    '🤔': 'تفکر',
    '😜': 'شوخی'
}

# %% [markdown]
# # Preprocessing tweets

# %%
import re
from hazm import Normalizer, Stemmer, word_tokenize


normalizer = Normalizer()
stemmer = Stemmer()


def preprocess_tweet(tweet , stop_words , emoji_mapping):
    tweet = re.sub(r'http\S+|www\S+|<\S+>', '', tweet, flags=re.MULTILINE)

    tweet = re.sub(r'(.)\1+', r'\1', tweet)

    tweet = normalizer.normalize(tweet)
    words = word_tokenize(tweet)

    words = [word for word in words if word not in stopwords]


    for emoji, text in emoji_mapping.items():
        tweet = tweet.replace(emoji, text)

    stemmed_words = [word for word in words]

    return ' '.join(stemmed_words)

df['preprocessed_tweet'] = df['tweet'].apply(lambda x: preprocess_tweet(x, stopwords, emoji_mapping))

# df.sample(7)[['hashtags' , 'tweet', 'emotion', 'preprocessed_tweet']]

# %% [markdown]
# # Tokenizing

# %%
import torch
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("HooshvareLab/bert-base-parsbert-uncased" , force_download=True)

def tokenize_and_pad(text):
    tokens = tokenizer(text, padding=True, truncation=True, max_length=32, return_tensors="pt")
    return tokens["input_ids"]


df['ids'] = df['preprocessed_tweet'].apply(tokenize_and_pad)
# df.sample(7)[['hashtags' , 'tweet', 'emotion', 'preprocessed_tweet' , 'ids']]
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/434 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.22M [00:00<?, ?B/s]

# %% [markdown]
# # Custom Dataset

# %%
from sklearn.model_selection import train_test_split

train_data, temp_data = train_test_split(df, test_size=0.3, random_state=42)
val_data, test_data = train_test_split(temp_data, test_size=0.33, random_state=42)


train_data.reset_index(drop=True, inplace=True)
val_data.reset_index(drop=True, inplace=True)
test_data.reset_index(drop=True, inplace=True)

# %%
from torch.utils.data import Dataset

emotion_to_label = {
    'anger': 0,
    'disgust': 1,
    'fear': 2,
    'joy': 3,
    'sad': 4,
    'surprise': 5
}


class CustomDataset(Dataset):
    def __init__(self, data, tokenizer, max_length):
        self.data = data
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        text = self.data.iloc[idx]['preprocessed_tweet']
        emotion = self.data.iloc[idx]['emotion']

        label = emotion_to_label[emotion]
        tokens = self.tokenizer(text, padding='max_length', truncation=True, max_length=self.max_length, return_tensors='pt')


        input_ids = tokens
        # padding_length = self.max_length - input_ids.shape[1]
        # if padding_length > 0:
        #     input_ids = torch.cat([input_ids, torch.zeros((1, padding_length), dtype=torch.long)], dim=1)



        return {
            'text' : text ,
            'input_ids': input_ids,
            'label': torch.tensor(label)
        }


tokenizer = AutoTokenizer.from_pretrained("HooshvareLab/bert-base-parsbert-uncased")

train_dataset = CustomDataset(train_data, tokenizer , max_length=32)
val_dataset   = CustomDataset(val_data  , tokenizer , max_length=32)
test_dataset  = CustomDataset(test_data,  tokenizer , max_length=32)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %% [markdown]
# # CNN Model

# %%
ids = train_data['preprocessed_tweet'].apply(tokenize_and_pad)

vocab_size = len(ids)

print(f'vocab_size  : {vocab_size}')
# Out:
# vocab_size  : 79680

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class CNN_Text(nn.Module):
    def __init__(self, vocab_size, embedding_dim, num_filters, filter_sizes, output_dim, dropout, pad_idx, unk_idx):
        super(CNN_Text, self).__init__()
        self.vocab_size = vocab_size

        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=pad_idx)
        self.unk_idx = unk_idx

        self.convs = nn.ModuleList([
            nn.Conv2d(1, num_filters, (fs, embedding_dim))
            for fs in filter_sizes
        ])

        self.fc = nn.Linear(len(filter_sizes) * num_filters, output_dim)

        self.dropout = nn.Dropout(dropout)

    def forward(self, text):
        # Replace out-of-vocabulary indices with UNK index
        text = torch.where(text < self.vocab_size, text, torch.tensor(self.unk_idx, device=text.device))
        # print(f'text : {text}')

        embedded = self.embedding(text)
        embedded = embedded.unsqueeze(1)

        conved = [F.relu(conv(embedded)).squeeze(3) for conv in self.convs]
        pooled = [F.max_pool1d(conv, conv.shape[2]).squeeze(2) for conv in conved]

        cat = self.dropout(torch.cat(pooled, dim=1))

        return self.fc(cat)


embedding_dim = 120
num_filters = 100
filter_sizes = [3, 4, 5]
output_dim = 6
dropout = 0.5
pad_idx = 0
unk_idx = vocab_size - 1


model = CNN_Text(vocab_size, embedding_dim, num_filters, filter_sizes, output_dim, dropout, pad_idx, unk_idx)

# %% [markdown]
# # Finding Optimal Hyperparameters

# %%
print(f'vocab_size  : {vocab_size}')
# Out:
# vocab_size  : 79680

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim import Adam, SGD

# hyperparameters
batch_sizes = [64, 8]
learning_rates = [0.001, 0.0001]
optimizers = {'Adam': Adam, 'SGD': SGD}

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def train_model(model, criterion, optimizer, train_loader, val_loader, num_epochs=10):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        train_correct = 0
        train_total = 0
        for batch in train_loader:
            data = batch['input_ids']['input_ids'].to(device)
            targets = batch['label'].to(device)

            data = data.squeeze(1)
            optimizer.zero_grad()
            outputs = model(data)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            train_total += targets.size(0)
            train_correct += (predicted == targets).sum().item()

        train_loss /= len(train_loader)
        train_accuracy = 100 * train_correct / train_total
        print(f'Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%')

        # Validation phase
        model.eval()
        val_loss = 0
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for batch in val_loader:
                data = batch['input_ids']['input_ids'].to(device)
                targets = batch['label'].to(device)
                data = data.squeeze(1)
                outputs = model(data)
                val_loss += criterion(outputs, targets).item()

                _, predicted = torch.max(outputs.data, 1)
                val_total += targets.size(0)
                val_correct += (predicted == targets).sum().item()

        val_loss /= len(val_loader)
        val_accuracy = 100 * val_correct / val_total
        print(f'Epoch {epoch+1}, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%')

# Assuming the CNN_Text model and datasets are defined correctly
model = CNN_Text(vocab_size, embedding_dim, num_filters, filter_sizes, output_dim=6, dropout=0.1, pad_idx=0, unk_idx=unk_idx)
criterion = nn.CrossEntropyLoss().to(device)

for batch_size in batch_sizes:
    for lr in learning_rates:import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim import Adam, SGD

# hyperparameters
batch_sizes = [64, 8]
learning_rates = [0.001, 0.0001]
optimizers = {'Adam': Adam, 'SGD': SGD}

…
            train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=batch_size)

            optimizer = Optimizer(model.parameters(), lr=lr)
            train_model(model, criterion, optimizer, train_loader, val_loader)

        for opt_name, Optimizer in optimizers.items():
            print(f'Testing batch size {batch_size}, learning ratne {lr}, optimizer {opt_name}')

            train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=batch_size)

            optimizer = Optimizer(model.parameters(), lr=lr)
            train_model(model, criterion, optimizer, train_loader, val_loader)
# Out:
# Testing batch size 64, learning ratne 0.001, optimizer Adam
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# Epoch 1, Train Loss: 0.6757, Train Accuracy: 75.88%
# Epoch 1, Validation Loss: 0.3914, Validation Accuracy: 86.95%
# Epoch 2, Train Loss: 0.3376, Train Accuracy: 89.03%
# Epoch 2, Validation Loss: 0.3667, Validation Accuracy: 87.95%
# Epoch 3, Train Loss: 0.2618, Train Accuracy: 91.54%
# Epoch 3, Validation Loss: 0.3876, Validation Accuracy: 87.88%
# Epoch 4, Train Loss: 0.2135, Train Accuracy: 93.28%
# Epoch 4, Validation Loss: 0.4143, Validation Accuracy: 87.77%
# Epoch 5, Train Loss: 0.1782, Train Accuracy: 94.61%
# Epoch 5, Validation Loss: 0.4520, Validation Accuracy: 87.30%
# Epoch 6, Train Loss: 0.1590, Train Accuracy: 95.38%
# Epoch 6, Validation Loss: 0.4682, Validation Accuracy: 87.46%
# Epoch 7, Train Loss: 0.1471, Train Accuracy: 95.88%
# Epoch 7, Validation Loss: 0.4698, Validation Accuracy: 87.72%
# Epoch 8, Train Loss: 0.1401, Train Accuracy: 96.23%
# Epoch 8, Validation Loss: 0.4917, Validation Accuracy: 87.39%
# Epoch 9, Train Loss: 0.1311, Train Accuracy: 96.40%
# Epoch 9, Validation Loss: 0.4943, Validation Accuracy: 87.76%
# Epoch 10, Train Loss: 0.1282, Train Accuracy: 96.52%
# Epoch 10, Validation Loss: 0.5133, Validation Accuracy: 87.27%
# Testing batch size 64, learning ratne 0.001, optimizer SGD
# Epoch 1, Train Loss: 0.0811, Train Accuracy: 97.75%
# Epoch 1, Validation Loss: 0.4782, Validation Accuracy: 87.82%
# Epoch 2, Train Loss: 0.0793, Train Accuracy: 97.75%
# Epoch 2, Validation Loss: 0.4774, Validation Accuracy: 87.77%
# Epoch 3, Train Loss: 0.0780, Train Accuracy: 97.77%
# Epoch 3, Validation Loss: 0.4781, Validation Accuracy: 87.76%
# Epoch 4, Train Loss: 0.0784, Train Accuracy: 97.76%
# Epoch 4, Validation Loss: 0.4769, Validation Accuracy: 87.77%
# Epoch 5, Train Loss: 0.0771, Train Accuracy: 97.82%
# Epoch 5, Validation Loss: 0.4761, Validation Accuracy: 87.77%
# Epoch 6, Train Loss: 0.0749, Train Accuracy: 97.82%
# Epoch 6, Validation Loss: 0.4758, Validation Accuracy: 87.76%
# Epoch 7, Train Loss: 0.0748, Train Accuracy: 97.81%
# Epoch 7, Validation Loss: 0.4767, Validation Accuracy: 87.71%
