# %% [markdown]
# # Importing Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Test SHOULD BE DELETED

# %%
# !wget # -P "/content/drive/MyDrive/NNDL_HW6/data/AnimeFaces" \
# "https://storage.googleapis.com/kaggle-data-sets/379764/737475/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240617%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240617T092231Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..." \
# -O animefacedataset.zip

# !unzip animefacedataset.zip -d anime_face_dataset
# Out:
# wget: missing URL
# Usage: wget [OPTION]... [URL]...
#
# Try `wget --help' for more options.
# unzip:  cannot find or open animefacedataset.zip, animefacedataset.zip.zip or animefacedataset.zip.ZIP.

# %%
# !mkdir /content/drive/MyDrive/NNDL_HW6/data/AnimeCartoons

# !wget -P "content/drive/MyDrive/NNDL_HW6/data/AnimeCartoons" \
# "https://storage.googleapis.com/kaggle-data-sets/1852588/3024951/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240617%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240617T083157Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..." -O cartoon-face.zip

# !unzip cartoon-face.zip -d cartoon_face_dataset
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/NNDL_HW6/data/AnimeCartoons’: File exists
# --2024-06-20 15:20:47--  https://storage.googleapis.com/kaggle-data-sets/1852588/3024951/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240617%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240617T083157Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.141.207, 142.251.2.207, 74.125.137.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.141.207|:443... connected.
# HTTP request sent, awaiting response... 400 Bad Request
# 2024-06-20 15:20:48 ERROR 400: Bad Request.
#
# Archive:  cartoon-face.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of cartoon-face.zip or
#         cartoon-face.zip.zip, and cannot find cartoon-face.zip.ZIP, period.

# %%
# !pip install kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# import os
# from kaggle.api.kaggle_api_extended import KaggleApi

# api = KaggleApi()
# api.authenticate()

# anime_faces_dataset_path = '/content/drive/MyDrive/NNDL_HW6/data/AnimeFaces'
# cartoon_faces_dataset_path = '/content/drive/MyDrive/NNDL_HW6/data/CartoonFaces'

# os.makedirs(anime_faces_dataset_path, exist_ok=True)
# os.makedirs(cartoon_faces_dataset_path, exist_ok=True)

# anime_faces_dataset_url = 'splcher/animefacedataset'
# api.dataset_download_files(anime_faces_dataset_url, path=anime_faces_dataset_path, unzip=True)

# cartoon_faces_dataset_url = 'brendanartley/cartoon-faces-googles-cartoon-set'
# api.dataset_download_files(cartoon_faces_dataset_url, path=cartoon_faces_dataset_path, unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/splcher/animefacedataset
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-a0fccf581157> in <cell line: 15>()
#      13
#      14 anime_faces_dataset_url = 'splcher/animefacedataset'
# ---> 15 api.dataset_download_files(anime_faces_dataset_url, path=anime_faces_dataset_path, unzip=True)
#      16
#      17 cartoon_faces_dataset_url = 'brendanartley/cartoon-faces-googles-cartoon-set'
#
# /usr/local/lib/python3.10/dist-packages/kaggle/api/kaggle_api_extended.py in dataset_download_files(self, dataset, path, force, quiet, unzip, licenses)
#    1507                 try:
#    1508                     with zipfile.ZipFile(outfile) as z:
# -> 1509                         z.extractall(effective_path)
#    1510                 except zipfile.BadZipFile as e:
#    1511                     raise ValueError(
#
# /usr/lib/python3.10/zipfile.py in extractall(self, path, members, pwd)
#    1645
#    1646         for zipinfo in members:
# -> 1647             self._extract_member(zipinfo, path, pwd)
#    1648
#    1649     @classmethod
#
# /usr/lib/python3.10/zipfile.py in _extract_member(self, member, targetpath, pwd)
#    1698             return targetpath
#    1699
# -> 1700         with self.open(member, pwd=pwd) as source, \
#    1701              open(targetpath, "wb") as target:
#    1702             shutil.copyfileobj(source, target)
#
# KeyboardInterrupt:

# %%
# !kaggle datasets download -d

# %%
# !kaggle datasets download -d splcher/animefacedataset

# !unzip animefacedataset.zip -d /content/drive/MyDrive/NNDL_HW6/data/AnimeFaces

# !cp -r /content/animefacedataset /content/drive/MyDrive/NNDL_HW6/data/AnimeFaces

# %%
# # https://www.kaggle.com/datasets/brendanartley/cartoon-faces-googles-cartoon-set/data

# !kaggle datasets download -d brendanartley/cartoon-faces-googles-cartoon-set

# !unzip cartoon-faces-googles-cartoon-set.zip -d /content/drive/MyDrive/NNDL_HW6/data/CartoonFaces

# !cp -r /content/cartoon_faces /content/drive/MyDrive/NNDL_HW6/data/CartoonFaces

# %% [markdown]
# # AnimeFaces Dataset

# %%
import matplotlib.pyplot as plt
from torchvision import datasets, transforms
from torch.utils.data import DataLoader


transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor()
])

rootdir = '/content/drive/MyDrive/NNDL_HW6/data/AnimeFaces/'

dataset = datasets.ImageFolder(root = rootdir , transform=transform)
dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

images, labels = next(iter(dataloader))
# plt.imshow(images[random.randint(0 , len(images))].permute(1, 2, 0))
# plt.show()
print(len(images))
# Out:
# 64

# %%
import os

dir_path = '/content/drive/MyDrive/NNDL_HW6/data/AnimeFaces/images'
count = 0

for path in os.listdir(dir_path):
    if os.path.isfile(os.path.join(dir_path, path)):
        count += 1
print('File count:', count) # 63,565
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-47d1fe2d114a> in <cell line: 6>()
#       5
#       6 for path in os.listdir(dir_path):
# ----> 7     if os.path.isfile(os.path.join(dir_path, path)):
#       8         count += 1
#       9 print('File count:', count) # 63,565
#
# /usr/lib/python3.10/genericpath.py in isfile(path)
#      28     """Test whether a path is a regular file"""
#      29     try:
# ---> 30         st = os.stat(path)
#      31     except (OSError, ValueError):
#      32         return False
#
# KeyboardInterrupt:

# %%
print(len(images))
import random
length = len(images)

for i in range(5):
  random_num = random.randint(0 , length)
  images, labels = next(iter(dataloader))
  plt.imshow(images[random_num].permute(1, 2, 0))
  plt.show()
# Out:
# 64

# %%
import torch
from torch import nn, optim


class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 16, 3, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(16, 32, 3, stride=2, padding=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(32 * 16 * 16, 128),
            nn.ReLU(),
            nn.Linear(128, 20)
        )
        self.decoder = nn.Sequential(
            nn.Linear(10, 128),
            nn.ReLU(),
            nn.Linear(128, 32 * 16 * 16),
            nn.ReLU(),
            nn.Unflatten(1, (32, 16, 16)),
            nn.ConvTranspose2d(32, 16, 3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(16, 3, 3, stride=2, padding=1, output_padding=1),
            nn.Sigmoid()
        )

    def reparameterize(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        x = self.encoder(x)
        mu = x[:, :10]
        log_var = x[:, 10:]
        z = self.reparameterize(mu, log_var)
        return self.decoder(z), mu, log_var

model = VAE()
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()


for epoch in range(3):
    for images, _ in dataloader:
        reconstruction, mu, log_var = model(images)
        loss = criterion(reconstruction, images) + \
               -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-f5c6e68b6c6c> in <cell line: 47>()
#      46
#      47 for epoch in range(3):
# ---> 48     for images, _ in dataloader:
#      49         reconstruction, mu, log_var = model(images)
#      50         loss = criterion(reconstruction, images) + \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     629                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630                 self._reset()  # type: ignore[call-arg]
# --> 631             data = self._next_data()
#     632             self._num_yielded += 1
#     633             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     673     def _next_data(self):
#     674         index = self._next_index()  # may raise StopIteration
# --> 675         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676         if self._pin_memory:
#     677             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in __getitem__(self, index)
#     243         """
#     244         path, target = self.samples[index]
# --> 245         sample = self.loader(path)
#     246         if self.transform is not None:
#     247             sample = self.transform(sample)
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in default_loader(path)
#     282         return accimage_loader(path)
#     283     else:
# --> 284         return pil_loader(path)
#     285
#     286
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in pil_loader(path)
#     261     # open path as file to avoid ResourceWarning (https://github.com/python-pillow/Pillow/issues/835)
#     262     with open(path, "rb") as f:
# --> 263         img = Image.open(f)
#     264         return img.convert("RGB")
#     265
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3172
#    3173
# -> 3174 def open(fp, mode="r", formats=None):
#    3175     """
#    3176     Opens and identifies the given image file.
#
# KeyboardInterrupt:

# %% [markdown]
# # CartoonFaces Dataset

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import os
import random

root_dir = '/content/drive/MyDrive/NNDL_HW6/data/CartoonFaces/cartoonset100k_jpg'

selected_folders = random.sample(range(10), 5)
print(selected_folders)

folder_paths = [os.path.join(root_dir, str(folder)) for folder in selected_folders]

transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
])


dataset = datasets.ImageFolder(root = folder_paths , transform=transform)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
# Out:
# [6, 7, 3, 8, 1]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-e4e5ae4aeb9e> in <cell line: 22>()
#      20
#      21
# ---> 22 dataset = datasets.ImageFolder(root = folder_paths , transform=transform)
#      23 dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file, allow_empty)
#     326         allow_empty: bool = False,
#     327     ):
# --> 328         super().__init__(
#     329             root,
#     330             loader,
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file, allow_empty)
#     147     ) -> None:
#     148         super().__init__(root, transform=transform, target_transform=target_transform)
# --> 149         classes, class_to_idx = self.find_classes(self.root)
#     150         samples = self.make_dataset(
#     151             self.root,
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in find_classes(self, directory)
#     232             (Tuple[List[str], Dict[str, int]]): List of all classes and dictionary mapping each class to an index.
#     233         """
# --> 234         return find_classes(directory)
#     235
#     236     def __getitem__(self, index: int) -> Tuple[Any, Any]:
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in find_classes(directory)
#      39     See :class:`DatasetFolder` for details.
#      40     """
# ---> 41     classes = sorted(entry.name for entry in os.scandir(directory) if entry.is_dir())
#      42     if not classes:
#      43         raise FileNotFoundError(f"Couldn't find any class folder in {directory}.")
#
# TypeError: scandir: path should be string, bytes, os.PathLike, integer or None, not list

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import os
import random
from PIL import Image

class MultiFolderDataset(Dataset):
    def __init__(self, folder_paths, transform=None):
        self.folder_paths = folder_paths
        self.transform = transform
        self.image_paths = []
        self.labels = []
        self._load_images()

    def _load_images(self):
        for label, folder_path in enumerate(self.folder_paths):
            for root, _, files in os.walk(folder_path):
                for file in files:
                    if file.endswith(('jpg', 'jpeg', 'png')):
                        self.image_paths.append(os.path.join(root, file))
                        self.labels.append(label)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert('RGB')
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

root_dir = '/content/drive/MyDrive/NNDL_HW6/data/CartoonFaces/cartoonset100k_jpg'

selected_folders = random.sample(range(10), 1)
print("Selected folders:", selected_folders)

folder_paths = [os.path.join(root_dir, str(folder)) for folder in selected_folders]

transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
])


dataset = MultiFolderDataset(folder_paths, transform=transform)


dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
# Out:
# Selected folders: [1]

# %%
import matplotlib.pyplot as plt

for i in range(5):
  images, labels = next(iter(dataloader))
  plt.imshow(images[random.randint(0 , len(images) - 1)].permute(1, 2, 0))
  plt.show()
  print(len(images))
# Out:
# 32
# 32
# 32
# 32
# 32

# %%
import torch
from torch import nn, optim


class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 16, 3, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(16, 32, 3, stride=2, padding=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(32 * 16 * 16, 128),
            nn.ReLU(),
            nn.Linear(128, 20)
        )
        self.decoder = nn.Sequential(
            nn.Linear(10, 128),
            nn.ReLU(),
            nn.Linear(128, 32 * 16 * 16),
            nn.ReLU(),
            nn.Unflatten(1, (32, 16, 16)),
            nn.ConvTranspose2d(32, 16, 3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(16, 3, 3, stride=2, padding=1, output_padding=1),
            nn.Sigmoid()
        )

    def reparameterize(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        x = self.encoder(x)
        mu = x[:, :10]
        log_var = x[:, 10:]
        z = self.reparameterize(mu, log_var)
        return self.decoder(z), mu, log_var

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device : {device}')


model = VAE().to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()


for epoch in range(3):
    for images, _ in dataloader:
        images = images.to(device)
        reconstruction, mu, log_var = model(images)
        loss = criterion(reconstruction, images) + \
               -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')
# Out:
# Using device : cuda
# Epoch 1, Loss: 0.02699790522456169
# Epoch 2, Loss: 0.021832522004842758
# Epoch 3, Loss: 0.017737364396452904

# %%
import torch
import matplotlib.pyplot as plt

def generate_images(model, num_images = 8):
    model.eval()
    with torch.no_grad():
        z = torch.randn(num_images, 10).to(device)

        # 10 is the dimension of the latent space
        generated_images = model.decoder(z)

    return generated_images


num_images_to_generate = 5
generated_images = generate_images(model.to(device), num_images=8)


def show_images(images):
    fig, axes = plt.subplots(nrows=1, ncols=len(images), figsize=(15, 3))
    for ax, img in zip(axes, images):
        img = img.cpu()
        ax.imshow(img.permute(1, 2, 0).numpy())
        # Convert from (C, H, W) to (H, W, C)
        ax.axis('off')
    plt.show()


show_images([img.squeeze(0) for img in generated_images[: 20]])

# %% [markdown]
# # Conditional VAE

# %%
import torch
from torch import nn, optim

class CVAE(nn.Module):
    def __init__(self, num_conditions):
        super(CVAE, self).__init__()
        # Expanded input for encoder to include condition
        self.encoder = nn.Sequential(
            nn.Conv2d(3 + num_conditions, 16, 3, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(16, 32, 3, stride=2, padding=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(32 * 16 * 16, 128),
            nn.ReLU(),
            nn.Linear(128, 20)  # Output mu and log_var
        )

        # Decoder takes both z and condition
        self.decoder = nn.Sequential(
            nn.Linear(10 + num_conditions, 128),
            nn.ReLU(),
            nn.Linear(128, 32 * 16 * 16),
            nn.ReLU(),
            nn.Unflatten(1, (32, 16, 16)),
            nn.ConvTranspose2d(32, 16, 3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(16, 3, 3, stride=2, padding=1, output_padding=1),
            nn.Sigmoid()
        )

    def reparameterize(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x, c):
        # Reshape and expand condition to match image dimensions
        batch_size, _, height, width = x.size()
        c = c.reshape(batch_size, -1, 1, 1)  # Reshape to (batch_size, num_conditions, 1, 1)
        c = c.expand(batch_size, -1, height, width)  # Expand to match x dimensions

        # Concatenate along the channel dimension
        x = torch.cat([x, c], dim=1)
        x = self.encoder(x)
        mu = x[:, :10]
        log_var = x[:, 10:]
        z = self.reparameterize(mu, log_var)

        # Concatenate z with the condition vector for the decoder
        z = torch.cat([z, c.reshape(batch_size, -1)], dim=1)
        return self.decoder(z), mu, log_var

# Assuming num_conditions is the size of the conditioning vector
num_conditions = 10  # Change this based on your dataset
model = CVAE(num_conditions=num_conditions)
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()

# Example use in training
for epoch in range(3):
    for images, labels in dataloader:
        # Assuming labels are available and one-hot encoded
        c = torch.nn.functional.one_hot(labels, num_classes=num_conditions).float()

        # Forward pass with images and condition vector
        reconstruction, mu, log_var = model(images, c)

        # Compute the loss
        reconstruction_loss = criterion(reconstruction, images)
        kl_divergence = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
        loss = reconstruction_loss + kl_divergence

        # Backpropagation and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f'Epoch {epoch+1}, Loss: {loss.item()}')
